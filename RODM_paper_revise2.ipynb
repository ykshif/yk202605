# %%
#import packages
import time
import numpy as np
import capytaine as cpt
import scipy
from capytaine.io.mesh_writers import write_STL
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
from scipy.linalg import eigh
import vtk
import logging
import xarray as xr
from capytaine.io.xarray import merge_complex_values
from capytaine.post_pro import rao
logging.basicConfig(level=logging.INFO, format='%(levelname)-8s: %(message)s')
# user defined functions
import DM_ShowNodes as DMshow
import DM_Reading as dm_r
import DM_Assemble as DM_A
import SEREP as SEREP

# %%
dataset = merge_complex_values(xr.open_dataset("E:\phd\Code\DM-FEM2D\HydrodynamicData\Yoga\DM1_direction0_paperrevise_1.nc"))

# %%
plt.plot(dataset.omega,dataset["added_mass"][:,4::6,4::6].values[:,0,0])
# plt.plot(dataset.omega,abs(dataset["added_mass"][:,2::6,2::6].values[:,1,1]))
# plt.plot(dataset.omega,abs(dataset["added_mass"][:,2::6,2::6].values[:,2,2]))
# plt.plot(dataset.omega,abs(dataset["added_mass"][:,2::6,2::6].values[:,3,3]))
# plt.plot(dataset.omega,abs(dataset["added_mass"][:,2::6,2::6].values[:,4,4]))
# plt.plot(dataset.omega,abs(dataset["added_mass"][:,2::6,2::6].values[:,5,5]))
# plt.plot(dataset.omega,abs(dataset["added_mass"][:,2::6,2::6].values[:,6,6]))

# %%
plt.plot(dataset.omega,dataset["radiation_damping"].values[:,4,4])

# %%
kk = dataset["hydrostatic_stiffness"].values

# %%
print(kk)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.76580000e+08 -0.00000000e+00
#    9.52884875e-06  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -0.00000000e+00  5.28489225e+10
#    0.00000000e+00  2.91193573e-04]
#  [ 0.00000000e+00  0.00000000e+00  9.52884875e-06  0.00000000e+00
#    1.32422492e+12 -3.76402909e-09]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]]

# %%
plt.plot(dataset.omega,abs(dataset["radiation_damping"].values[:,2,2]))

# %%
dataset["added_mass"][0]
